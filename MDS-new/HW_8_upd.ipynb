# %% [markdown]
# # Домашнее задание "Случайные величины и вероятности".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# В магазин привезли устройства с 3-х разных предприятий.
#
# Соотношение устройств следующее: 20% - продукция первого предприятия, 30% - продукция второго предприятия, 50% - продукция третьего предприятия; далее, 10% продукции первого предприятия высшего сорта, на втором предприятии - 5% и на третьем - 20% продукции высшего сорта.
#
# Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %%
import random

# 2 1.5 10 = 13.5%
# 0.2*0.1 + 0.3*0.05 + 0.5*0.2 = 0.135
# Out:
# 382 617

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Пусть брошены 3 уравновешенные монеты.
#
# Рассмотрим 3 события:
#
# A1 - монеты 1 и 2 упали одной и той же стороной;
#
# A2 - монеты 2 и 3 упали одной и той же стороной;
#
# A3 - монеты 1 и 3 упали одной и той же стороной.
#
# Покажите, почему эти 3 события (A1, A2, A3) являются попарно независимыми, но не являются независимыми в совокупности.

# %% [markdown]
# **вероятнее всего потому, что:**
# в 2х случаях вероятность выпадения одной стороной равна 0.5
# в 3х случаях вероятность выпадения одной стороной равна 0.25
# Совместная вероятность выпадения одной стороны для 3х событий 2/8 = 0.25
# однако
# Произведение индивидуальных вероятностей: 1/8 = 0.125
# однако я ничего не понимаю, предположу, что выпадение первой монетки не влияет на верноятность выпадению обеих одной стороной, но если вторая выпадает   неправильной строной то это влияет на совокупную вероятность после выпадения 3-й

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Изучите 3 распределения из библиотеки scipy: [Нормальное](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html), [Экспоненциальное](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html), [Стьюдента](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.t.html). Используя функцию плотности распредления (`pdf`), постройте пять графиков плотностей для каждого распределения при разных параметрах. Запишите ваши наблюдения: как и на что влияют параметры у каждого распределения.
#
# Дополнительная информация [тут](https://pythonguides.com/scipy-stats/).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, t

params = {
    'norm': {
        'loc': [0, 0, 0],
        'scale': [1, 2, 0.5]
    },
    'expon': {
        'scale': [1, 2, 0.5]
    },
    't': {
        'df': [1, 5, 30],
        'loc': [0, 0, 0],
        'scale': [1, 2, 0.3]
    }
}

x = np.linspace(-10, 10, 100)
x_non_neg = np.linspace(0, 10, 100)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

for loc, scale in zip(params['norm']['loc'], params['norm']['scale']):
    axs[0].plot(x, norm.pdf(x, loc, scale), label=f'loc={loc}, scale={scale}')
axs[0].set_title('Normal Distribution')
axs[0].legend()

for scale in params['expon']['scale']:
    axs[1].plot(x_non_neg,
                expon.pdf(x_non_neg, scale=scale),
                label=f'scale={scale}')
axs[1].set_title('Exponential Distribution')
axs[1].legend()

for df, loc, scale in zip(params['t']['df'], params['t']['loc'], params['t']['scale']):
    axs[2].plot(x, t.pdf(x, df, loc=loc, scale=scale),
                label=f'df={df}, loc={loc}, scale={scale}')
axs[2].set_title('t Distribution')
axs[2].legend()

plt.tight_layout()
plt.show()
